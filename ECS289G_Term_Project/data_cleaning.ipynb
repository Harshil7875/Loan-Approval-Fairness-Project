# %%
# ECS289G_Term_Project/data_cleaning.ipynb

# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
file_path = r"/Users/harshil/Developer/GitHub_Repos/ECS_289G/data/raw/state_CA-WA-NJ-CT.csv"
df = pd.read_csv(file_path, low_memory=False)

# Display initial dataset information
print(f"Dataset Shape: {df.shape}")
df.head()
df.info()
# Out:
# Dataset Shape: (1602362, 99)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1602362 entries, 0 to 1602361
# Data columns (total 99 columns):
#  #   Column                                    Non-Null Count    Dtype
# ---  ------                                    --------------    -----
#  0   activity_year                             1602362 non-null  int64
#  1   lei                                       1602362 non-null  object
#  2   derived_msa-md                            1602362 non-null  int64
#  3   state_code                                1602362 non-null  object
#  4   county_code                               1589888 non-null  float64
#  5   census_tract                              1586190 non-null  float64
#  6   conforming_loan_limit                     1594356 non-null  object
#  7   derived_loan_product_type                 1602362 non-null  object
#  8   derived_dwelling_category                 1602362 non-null  object
#  9   derived_ethnicity                         1602362 non-null  object
#  10  derived_race                              1602362 non-null  object
#  11  derived_sex                               1602362 non-null  object
#  12  action_taken                              1602362 non-null  int64
#  13  purchaser_type                            1602362 non-null  int64
#  14  preapproval                               1602362 non-null  int64
#  15  loan_type                                 1602362 non-null  int64
#  16  loan_purpose                              1602362 non-null  int64
#  17  lien_status                               1602362 non-null  int64
#  18  reverse_mortgage                          1602362 non-null  int64
#  19  open-end_line_of_credit                   1602362 non-null  int64
#  20  business_or_commercial_purpose            1602362 non-null  int64
#  21  loan_amount                               1602362 non-null  float64
#  22  loan_to_value_ratio                       1041888 non-null  object
#  23  interest_rate                             1040165 non-null  object
#  24  rate_spread                               736551 non-null   object
#  25  hoepa_status                              1602362 non-null  int64
#  26  total_loan_costs                          705045 non-null   object
#  27  total_points_and_fees                     28769 non-null    object
#  28  origination_charges                       717686 non-null   object
#  29  discount_points                           384996 non-null   object
#  30  lender_credits                            239096 non-null   object
#  31  loan_term                                 1574365 non-null  object
#  32  prepayment_penalty_term                   111215 non-null   object
#  33  intro_rate_period                         457998 non-null   object
#  34  negative_amortization                     1602362 non-null  int64
#  35  interest_only_payment                     1602362 non-null  int64
#  36  balloon_payment                           1602362 non-null  int64
#  37  other_nonamortizing_features              1602362 non-null  int64
#  38  property_value                            1290352 non-null  object
#  39  construction_method                       1602362 non-null  int64
#  40  occupancy_type                            1602362 non-null  int64
#  41  manufactured_home_secured_property_type   1602362 non-null  int64
#  42  manufactured_home_land_property_interest  1602362 non-null  int64
#  43  total_units                               1602362 non-null  object
#  44  multifamily_affordable_units              24597 non-null    object
#  45  income                                    1345369 non-null  float64
#  46  debt_to_income_ratio                      1029698 non-null  object
#  47  applicant_credit_score_type               1602362 non-null  int64
#  48  co-applicant_credit_score_type            1602362 non-null  int64
#  49  applicant_ethnicity-1                     1600939 non-null  float64
#  50  applicant_ethnicity-2                     137081 non-null   float64
#  51  applicant_ethnicity-3                     2609 non-null     float64
#  52  applicant_ethnicity-4                     57 non-null       float64
#  53  applicant_ethnicity-5                     16 non-null       float64
#  54  co-applicant_ethnicity-1                  1601800 non-null  float64
#  55  co-applicant_ethnicity-2                  59018 non-null    float64
#  56  co-applicant_ethnicity-3                  929 non-null      float64
#  57  co-applicant_ethnicity-4                  18 non-null       float64
#  58  co-applicant_ethnicity-5                  4 non-null        float64
#  59  applicant_ethnicity_observed              1602362 non-null  int64
#  60  co-applicant_ethnicity_observed           1602362 non-null  int64
#  61  applicant_race-1                          1601544 non-null  float64
#  62  applicant_race-2                          149026 non-null   float64
#  63  applicant_race-3                          10328 non-null    float64
#  64  applicant_race-4                          1270 non-null     float64
#  65  applicant_race-5                          368 non-null      float64
#  66  co-applicant_race-1                       1602161 non-null  float64
#  67  co-applicant_race-2                       65555 non-null    float64
#  68  co-applicant_race-3                       4210 non-null     float64
#  69  co-applicant_race-4                       424 non-null      float64
#  70  co-applicant_race-5                       120 non-null      float64
#  71  applicant_race_observed                   1602362 non-null  int64
#  72  co-applicant_race_observed                1602362 non-null  int64
#  73  applicant_sex                             1602362 non-null  int64
#  74  co-applicant_sex                          1602362 non-null  int64
#  75  applicant_sex_observed                    1602362 non-null  int64
#  76  co-applicant_sex_observed                 1602362 non-null  int64
#  77  applicant_age                             1602362 non-null  object
#  78  co-applicant_age                          1602362 non-null  object
#  79  applicant_age_above_62                    1362831 non-null  object
#  80  co-applicant_age_above_62                 606463 non-null   object
#  81  submission_of_application                 1602362 non-null  int64
#  82  initially_payable_to_institution          1602362 non-null  int64
#  83  aus-1                                     1602362 non-null  int64
#  84  aus-2                                     85455 non-null    float64
#  85  aus-3                                     18765 non-null    float64
#  86  aus-4                                     5488 non-null     float64
#  87  aus-5                                     4728 non-null     float64
#  88  denial_reason-1                           1602362 non-null  int64
#  89  denial_reason-2                           62602 non-null    float64
#  90  denial_reason-3                           10603 non-null    float64
#  91  denial_reason-4                           1215 non-null     float64
#  92  tract_population                          1602362 non-null  int64
#  93  tract_minority_population_percent         1602362 non-null  float64
#  94  ffiec_msa_md_median_family_income         1602362 non-null  int64
#  95  tract_to_msa_income_percentage            1602362 non-null  float64
#  96  tract_owner_occupied_units                1602362 non-null  int64
#  97  tract_one_to_four_family_homes            1602362 non-null  int64
#  98  tract_median_age_of_housing_units         1602362 non-null  int64
# dtypes: float64(33), int64(39), object(27)
# memory usage: 1.2+ GB

# %%
# --- Step 1: Selecting Relevant Columns ---
# Columns to retain
columns_to_keep = [
    'tract_to_msa_income_percentage', 'ffiec_msa_md_median_family_income',
    'tract_minority_population_percent', 'interest_rate',
    'loan_type', 'loan_purpose', 'lien_status',
    'construction_method', 'occupancy_type',
    'derived_ethnicity', 'derived_race', 'derived_sex',
    'action_taken'
]

# Filter the dataset
filtered_data = df[columns_to_keep].copy()

# Verify selected columns
print(f"Filtered Dataset Shape: {filtered_data.shape}")
# Out:
# Filtered Dataset Shape: (1602362, 13)

# %%
# --- Step 2: Handling Missing Values ---
# Fill missing demographic values with placeholders
demographic_features = ['derived_ethnicity', 'derived_race', 'derived_sex']
for col in demographic_features:
    filtered_data[col] = filtered_data[col].fillna(f"{col.split('_')[-1]} Not Available")

# Handle non-numeric values in 'interest_rate'
filtered_data['interest_rate'] = pd.to_numeric(filtered_data['interest_rate'], errors='coerce')

# Check missing values
print("Missing Values Before Handling:")
print(filtered_data.isnull().sum())
# Out:
# Missing Values Before Handling:
# tract_to_msa_income_percentage            0
# ffiec_msa_md_median_family_income         0
# tract_minority_population_percent         0
# interest_rate                        580347
# loan_type                                 0
# loan_purpose                              0
# lien_status                               0
# construction_method                       0
# occupancy_type                            0
# derived_ethnicity                         0
# derived_race                              0
# derived_sex                               0
# action_taken                              0
# dtype: int64

# %%
# Step 2.1: Impute Missing 'interest_rate' Values with Median

# Calculate the median of the 'interest_rate' column
interest_rate_median = filtered_data['interest_rate'].median()
print(f"Median Interest Rate: {interest_rate_median}")

# Fill missing 'interest_rate' values with the median (avoiding inplace assignment)
filtered_data['interest_rate'] = filtered_data['interest_rate'].fillna(interest_rate_median)

# Verify that there are no more missing values in 'interest_rate'
missing_interest_rate_after = filtered_data['interest_rate'].isnull().sum()
print(f"Missing 'interest_rate' values after imputation: {missing_interest_rate_after}")
# Out:
# Median Interest Rate: 6.75
# Missing 'interest_rate' values after imputation: 0

# %%
# Check missing values
print("Missing Values Before Handling:")
print(filtered_data.isnull().sum())
# Out:
# Missing Values Before Handling:
# tract_to_msa_income_percentage       0
# ffiec_msa_md_median_family_income    0
# tract_minority_population_percent    0
# interest_rate                        0
# loan_type                            0
# loan_purpose                         0
# lien_status                          0
# construction_method                  0
# occupancy_type                       0
# derived_ethnicity                    0
# derived_race                         0
# derived_sex                          0
# action_taken                         0
# dtype: int64

# %%
# --- Step 3: Encoding Demographic Features ---
# Define encoding mappings
sex_mapping = {
    "Male": 0, "Female": 1, "Joint": 2, "Sex Not Available": 3
}

race_mapping = {
    "American Indian or Alaska Native": 0,
    "Asian": 1,
    "Black or African American": 2,
    "Native Hawaiian or Other Pacific Islander": 3,
    "White": 4,
    "2 or more minority races": 5,
    "Joint": 6,
    "Free Form Text Only": 7,
    "Race Not Available": 8
}

ethnicity_mapping = {
    "Hispanic or Latino": 0,
    "Not Hispanic or Latino": 1,
    "Joint": 2,
    "Ethnicity Not Available": 3,
    "Free Form Text Only": 4
}

# Map demographic features using the provided mappings
filtered_data["derived_sex"] = filtered_data["derived_sex"].map(sex_mapping)
filtered_data["derived_race"] = filtered_data["derived_race"].map(race_mapping)
filtered_data["derived_ethnicity"] = filtered_data["derived_ethnicity"].map(ethnicity_mapping)

# One-hot encoding for demographic features
race_one_hot = pd.get_dummies(filtered_data['derived_race'], prefix='race')
gender_one_hot = pd.get_dummies(filtered_data['derived_sex'], prefix='gender')
ethnicity_one_hot = pd.get_dummies(filtered_data['derived_ethnicity'], prefix='ethnicity')

# Combine with the main dataset
filtered_data = pd.concat([filtered_data, race_one_hot, gender_one_hot, ethnicity_one_hot], axis=1)

# Drop original demographic columns
filtered_data.drop(columns=['derived_race', 'derived_sex', 'derived_ethnicity'], inplace=True)

# --- Step 4: Encoding Other Categorical Features ---
# One-hot encoding for other categorical features
filtered_data = pd.get_dummies(filtered_data, columns=['loan_type', 'loan_purpose', 'lien_status',
                                                       'construction_method', 'occupancy_type'], drop_first=True)

# Verify transformations
print("Data After One-Hot Encoding:")
print(filtered_data.head())
# Out:
# Data After One-Hot Encoding:
#    tract_to_msa_income_percentage  ffiec_msa_md_median_family_income  \
# 0                          131.97                              76600
# 1                          128.98                             101700
# 2                           62.21                              94500
# 3                          108.93                             113900
# 4                           69.90                              94500
#
#    tract_minority_population_percent  interest_rate  action_taken  race_0  \
# 0                              19.02          6.000             6   False
# 1                              26.74          5.875             6   False
# 2                              49.51          6.000             6   False
# 3                              26.27          6.000             6   False
# 4                              43.85          6.375             6   False
#
#    race_1  race_2  race_3  race_4  ...  loan_type_4  loan_purpose_2  \
# 0   False   False   False   False  ...        False           False
# 1   False   False   False   False  ...        False           False
# 2   False   False   False   False  ...         True           False
# 3   False   False   False   False  ...        False           False
# 4   False   False   False   False  ...        False           False
#
#    loan_purpose_4  loan_purpose_5  loan_purpose_31  loan_purpose_32  \
# 0           False           False            False            False
# 1           False           False            False            False
# 2           False           False            False            False
# 3           False           False            False            False
# 4           False           False            False            False
#
#    lien_status_2  construction_method_2  occupancy_type_2  occupancy_type_3
# 0          False                  False             False             False
# 1          False                  False             False             False
# 2          False                  False             False             False
# 3          False                  False             False             False
# 4          False                   True             False             False
#
# [5 rows x 35 columns]

# %%
# --- Step 5: Saving the Cleaned Dataset ---
output_path = r"/Users/harshil/Developer/GitHub_Repos/ECS_289G/data/processsed/cleaned/cleaned_dataset_yrs-23.csv"
filtered_data.to_csv(output_path, index=False)

print(f"Cleaned dataset saved to {output_path}")
# Out:
# Cleaned dataset saved to /Users/harshil/Documents/UC Davis/Fall Quarter '24/ECS 289G/term_project/root_folder_1/data/processsed/cleaned_dataset_yrs-23.csv
