# %%
# ECS289G_Term_Project/adversarial_model.ipynb

import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %%
########################################
# Step 1: Load and Preprocess Data
########################################

path = "/Users/harshil/Developer/GitHub_Repos/ECS_289G/data/processsed/transformed/transformed_dataset-yrs-23.csv"
df = pd.read_csv(path, low_memory=False)

# Map action_taken to binary
loan_approved_mapping = {
    1: 1,  # Loan originated -> Approved
    2: 0,  # Approved but not accepted -> Denied
    3: 0,  # Denied
    4: 0,  # Withdrawn
    5: 0,  # Incomplete
    6: 1,  # Purchased
    7: 0,  # Preapproval denied
    8: 0   # Preapproval approved not accepted
}

df['loan_approved'] = df['action_taken'].map(loan_approved_mapping)
df_binary = df[df['loan_approved'].notnull()].copy()
df_binary['loan_approved'] = df_binary['loan_approved'].astype(int)
df_binary.drop('action_taken', axis=1, inplace=True)

# Sensitive features
sensitive_features = [
    'race_0', 'race_1', 'race_2', 'race_3', 'race_4',
    'race_5', 'race_6', 'race_7', 'race_8',
    'gender_0', 'gender_1', 'gender_2', 'gender_3',
    'ethnicity_0', 'ethnicity_1', 'ethnicity_2', 'ethnicity_3', 'ethnicity_4'
]

# Non-sensitive features for main model
feature_cols = [
    'tract_to_msa_income_percentage',
    'ffiec_msa_md_median_family_income',
    'tract_minority_population_percent',
    'interest_rate',
    'loan_type_2', 'loan_type_3', 'loan_type_4',
    'loan_purpose_2', 'loan_purpose_4', 'loan_purpose_5',
    'loan_purpose_31', 'loan_purpose_32',
    'lien_status_2',
    'construction_method_2',
    'occupancy_type_2', 'occupancy_type_3'
]

X = df_binary[feature_cols]
y = df_binary['loan_approved']
sensitive_attributes = df_binary[sensitive_features]

X_train, X_test, y_train, y_test, sensitive_train, sensitive_test = train_test_split(
    X, y, sensitive_attributes, test_size=0.2, random_state=42
)

print("Training set size:", X_train.shape[0])
print("Testing set size:", X_test.shape[0])

# Scale features
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Feature scaling completed")
# Out:
# Training set size: 1281889
# Testing set size: 320473
# Feature scaling completed

# %%
########################################
# Decode Sensitive Attributes for Groups
########################################

sensitive_train_simplified = sensitive_train.copy()
sensitive_test_simplified = sensitive_test.copy()

def get_race(row):
    race_mapping = {
        'race_0': 'American Indian or Alaska Native',
        'race_1': 'Asian',
        'race_2': 'Black or African American',
        'race_3': 'Native Hawaiian or Other Pacific Islander',
        'race_4': 'White',
        # Less common aggregated into 'Other'
        'race_5': 'Other', 'race_6': 'Other', 'race_7': 'Other',
        'race_8': 'Unknown or Not Applicable'
    }
    for col in race_mapping:
        if row[col] == 1:
            return race_mapping[col]
    return 'Unknown'

def get_gender(row):
    gender_mapping = {
        'gender_0': 'Male',
        'gender_1': 'Female',
        'gender_2': 'Joint',
        'gender_3': 'Unknown or Not Applicable'
    }
    for col in gender_mapping:
        if row[col] == 1:
            return gender_mapping[col]
    return 'Unknown'

def get_ethnicity(row):
    ethnicity_mapping = {
        'ethnicity_0': 'Hispanic or Latino',
        'ethnicity_1': 'Not Hispanic or Latino',
        'ethnicity_2': 'Joint',
        'ethnicity_3': 'Other',
        'ethnicity_4': 'Unknown or Not Applicable'
    }
    for col in ethnicity_mapping:
        if row[col] == 1:
            return ethnicity_mapping[col]
    return 'Unknown'

sensitive_train_simplified['race_group'] = sensitive_train_simplified.apply(get_race, axis=1)
sensitive_train_simplified['gender_group'] = sensitive_train_simplified.apply(get_gender, axis=1)
sensitive_train_simplified['ethnicity_group'] = sensitive_train_simplified.apply(get_ethnicity, axis=1)

sensitive_test_simplified['race_group'] = sensitive_test_simplified.apply(get_race, axis=1)
sensitive_test_simplified['gender_group'] = sensitive_test_simplified.apply(get_gender, axis=1)
sensitive_test_simplified['ethnicity_group'] = sensitive_test_simplified.apply(get_ethnicity, axis=1)

# Create a demographic_group column (Race_Gender combo)
sensitive_train_simplified['demographic_group'] = sensitive_train_simplified['race_group'] + '_' + sensitive_train_simplified['gender_group']
sensitive_test_simplified['demographic_group'] = sensitive_test_simplified['race_group'] + '_' + sensitive_test_simplified['gender_group']

# %%
########################################
# Resampling by group to handle imbalance
########################################

X_train_combined = pd.DataFrame(X_train_scaled, columns=feature_cols)
X_train_combined['demographic_group'] = sensitive_train_simplified['demographic_group'].values
X_train_combined['loan_approved'] = y_train.values
X_train_combined = X_train_combined.reset_index(drop=True)
sensitive_train_simplified = sensitive_train_simplified.reset_index(drop=True)

assert all(X_train_combined['demographic_group'] == sensitive_train_simplified['demographic_group']), "DataFrames not aligned!"

X_resampled_list = []
y_resampled_list = []
sensitive_resampled_list = []

for group in X_train_combined['demographic_group'].unique():
    group_indices = X_train_combined[X_train_combined['demographic_group'] == group].index
    X_group = X_train_combined.loc[group_indices, feature_cols]
    y_group = X_train_combined.loc[group_indices, 'loan_approved']
    sensitive_group = sensitive_train_simplified.loc[group_indices, ['race_group', 'gender_group', 'ethnicity_group']]

    class_counts = y_group.value_counts()
    total_samples = len(y_group)
    
    # Simple logic based on provided code
    if total_samples < 100:
        # No resampling
        X_resampled_list.append(X_group)
        y_resampled_list.append(y_group)
        sensitive_resampled_list.append(sensitive_group)
    elif total_samples > 100000:
        # Under-sample
        rus = RandomUnderSampler(random_state=42)
        X_resampled_group, y_resampled_group = rus.fit_resample(X_group, y_group)
        X_resampled_list.append(pd.DataFrame(X_resampled_group, columns=feature_cols))
        y_resampled_list.append(pd.Series(y_resampled_group))
        sensitive_resampled_group = sensitive_group.sample(n=len(y_resampled_group), replace=True, random_state=42).reset_index(drop=True)
        sensitive_resampled_list.append(sensitive_resampled_group)
    elif len(class_counts) < 2 or class_counts.min() < 6:
        # Over-sample
        ros = RandomOverSampler(random_state=42)
        X_resampled_group, y_resampled_group = ros.fit_resample(X_group, y_group)
        X_resampled_list.append(pd.DataFrame(X_resampled_group, columns=feature_cols))
        y_resampled_list.append(pd.Series(y_resampled_group))
        sensitive_resampled_group = sensitive_group.sample(n=len(y_resampled_group), replace=True, random_state=42).reset_index(drop=True)
        sensitive_resampled_list.append(sensitive_resampled_group)
    else:
        # SMOTE
        sm = SMOTE(random_state=42)
        X_resampled_group, y_resampled_group = sm.fit_resample(X_group, y_group)
        X_resampled_list.append(pd.DataFrame(X_resampled_group, columns=feature_cols))
        y_resampled_list.append(pd.Series(y_resampled_group))
        sensitive_resampled_group = sensitive_group.sample(n=len(y_resampled_group), replace=True, random_state=42).reset_index(drop=True)
        sensitive_resampled_list.append(sensitive_resampled_group)

X_train_resampled = pd.concat(X_resampled_list, axis=0).reset_index(drop=True)
y_train_resampled = pd.concat(y_resampled_list, axis=0).reset_index(drop=True)
sensitive_train_resampled = pd.concat(sensitive_resampled_list, axis=0).reset_index(drop=True)

print("Resampling completed.")
print(f"Original dataset size: {X_train.shape[0]}")
print(f"Resampled dataset size: {X_train_resampled.shape[0]}")

# Encode race, gender, ethnicity for adversaries
def encode_series(series):
    label_encoder = LabelEncoder()
    int_encoded = label_encoder.fit_transform(series)
    onehot_encoder = OneHotEncoder(sparse_output=False)
    int_encoded = int_encoded.reshape(-1, 1)
    onehot_encoded = onehot_encoder.fit_transform(int_encoded)
    return onehot_encoded, label_encoder

race_onehot, _ = encode_series(sensitive_train_resampled['race_group'])
gender_onehot, _ = encode_series(sensitive_train_resampled['gender_group'])
ethnicity_onehot, _ = encode_series(sensitive_train_resampled['ethnicity_group'])

X_train_input = X_train_resampled.values.astype('float32')
y_train_output = y_train_resampled.values.astype('float32').reshape(-1,1)
race_train_output = race_onehot.astype('float32')
gender_train_output = gender_onehot.astype('float32')
ethnicity_train_output = ethnicity_onehot.astype('float32')
# Out:
# Resampling completed.
# Original dataset size: 1281889
# Resampled dataset size: 1059588

# %%
########################################
# Adversarial Model Setup
########################################

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

class GradientReversalLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()

    @tf.custom_gradient
    def call(self, x):
        def grad(dy):
            return -dy
        return x, grad

inputs = Input(shape=(16,))
x = Dense(64, activation='relu')(inputs)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(32, activation='relu')(x)
x = Dropout(0.5)(x)
main_output = Dense(1, activation='sigmoid', name='main_output')(x)

grl_layer = GradientReversalLayer()(x)

# Race adversary
race_adv = Dense(64, activation='relu')(grl_layer)
race_adv = BatchNormalization()(race_adv)
race_adv = Dropout(0.5)(race_adv)
race_adversary_output = Dense(race_train_output.shape[1], activation='softmax', name='race_adversary_output')(race_adv)

# Gender adversary
gender_adv = Dense(64, activation='relu')(grl_layer)
gender_adv = BatchNormalization()(gender_adv)
gender_adv = Dropout(0.5)(gender_adv)
gender_adversary_output = Dense(gender_train_output.shape[1], activation='softmax', name='gender_adversary_output')(gender_adv)

# Ethnicity adversary
ethnicity_adv = Dense(64, activation='relu')(grl_layer)
ethnicity_adv = BatchNormalization()(ethnicity_adv)
ethnicity_adv = Dropout(0.5)(ethnicity_adv)
ethnicity_adversary_output = Dense(ethnicity_train_output.shape[1], activation='softmax', name='ethnicity_adversary_output')(ethnicity_adv)

combined_model = Model(inputs=inputs, outputs=[main_output, race_adversary_output, gender_adversary_output, ethnicity_adversary_output])

combined_model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss={
        'main_output': 'binary_crossentropy',
        'race_adversary_output': 'categorical_crossentropy',
        'gender_adversary_output': 'categorical_crossentropy',
        'ethnicity_adversary_output': 'categorical_crossentropy'
    },
    loss_weights={
        'main_output': 1.0,
        'race_adversary_output': 0.5,
        'gender_adversary_output': 0.5,
        'ethnicity_adversary_output': 0.5
    },
    metrics={
        'main_output': 'accuracy',
        'race_adversary_output': 'accuracy',
        'gender_adversary_output': 'accuracy',
        'ethnicity_adversary_output': 'accuracy'
    }
)

print(combined_model.summary())

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = combined_model.fit(
    X_train_input,
    {
        'main_output': y_train_output,
        'race_adversary_output': race_train_output,
        'gender_adversary_output': gender_train_output,
        'ethnicity_adversary_output': ethnicity_train_output
    },
    epochs=50,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 16)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64)        │      1,088 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 32)        │      2,080 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 32)        │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gradient_reversal_… │ (None, 32)        │          0 │ dropout_9[0][0]   │
# │ (GradientReversalL… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 64)        │      2,112 │ gradient_reversa… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 64)        │      2,112 │ gradient_reversa… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 64)        │      2,112 │ gradient_reversa… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_12[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 1)         │         33 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ race_adversary_out… │ (None, 7)         │        455 │ dropout_10[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_adversary_o… │ (None, 4)         │        260 │ dropout_11[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ethnicity_adversar… │ (None, 5)         │        325 │ dropout_12[0][0]  │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,601 (45.32 KB)
#  Trainable params: 11,089 (43.32 KB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/50
# 2024-12-10 14:15:21.308640: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 13245/13245 ━━━━━━━━━━━━━━━━━━━━ 612s 46ms/step - ethnicity_adversary_output_accuracy: 0.3991 - gender_adversary_output_accuracy: 0.3102 - loss: 3.1976 - main_output_accuracy: 0.5533 - race_adversary_output_accuracy: 0.4098 - val_ethnicity_adversary_output_accuracy: 0.7994 - val_gender_adversary_output_accuracy: 0.2959 - val_loss: 3.6752 - val_main_output_accuracy: 0.6596 - val_race_adversary_output_accuracy: 0.0325
# Epoch 2/50
# 13245/13245 ━━━━━━━━━━━━━━━━━━━━ 603s 46ms/step - ethnicity_adversary_output_accuracy: 0.5297 - gender_adversary_output_accuracy: 0.3693 - loss: 2.3513 - main_output_accuracy: 0.6422 - race_adversary_output_accuracy: 0.5715 - val_ethnicity_adversary_output_accuracy: 0.7994 - val_gender_adversary_output_accuracy: 0.3034 - val_loss: 3.6668 - val_main_output_accuracy: 0.8417 - val_race_adversary_output_accuracy: 0.0325
# Epoch 3/50
# 13245/13245 ━━━━━━━━━━━━━━━━━━━━ 612s 46ms/step - ethnicity_adversary_output_accuracy: 0.5316 - gender_adversary_output_accuracy: 0.3733 - loss: 2.2451 - main_output_accuracy: 0.7450 - race_adversary_output_accuracy: 0.5725 - val_ethnicity_adversary_output_accuracy: 0.7994 - val_gender_adversary_output_accuracy: 0.3003 - val_loss: 3.6794 - val_main_output_accuracy: 0.8697 - val_race_adversary_output_accuracy: 0.0325
# Epoch 4/50
# 13245/13245 ━━━━━━━━━━━━━━━━━━━━ 622s 47ms/step - ethnicity_adversary_output_accuracy: 0.5306 - gender_adversary_output_accuracy: 0.3719 - loss: 2.1831 - main_output_accuracy: 0.8038 - race_adversary_output_accuracy: 0.5727 - val_ethnicity_adversary_output_accuracy: 0.7994 - val_gender_adversary_output_accuracy: 0.3013 - val_loss: 3.6979 - val_main_output_accuracy: 0.8836 - val_race_adversary_output_accuracy: 0.0325
# Epoch 5/50
# 13245/13245 ━━━━━━━━━━━━━━━━━━━━ 619s 47ms/step - ethnicity_adversary_output_accuracy: 0.5305 - gender_adversary_output_accuracy: 0.3711 - loss: 2.1477 - main_output_accuracy: 0.8295 - race_adversary_output_accuracy: 0.5728 - val_ethnicity_adversary_output_accuracy: 0.7994 - val_gender_adversary_output_accuracy: 0.3031 - val_loss: 3.7430 - val_main_output_accuracy: 0.8873 - val_race_adversary_output_accuracy: 0.0325
# Epoch 6/50
# 13245/13245 ━━━━━━━━━━━━━━━━━━━━ 609s 46ms/step - ethnicity_adversary_output_accuracy: 0.5307 - gender_adversary_output_accuracy: 0.3702 - loss: 2.1224 - main_output_accuracy: 0.8450 - race_adversary_output_accuracy: 0.5725 - val_ethnicity_adversary_output_accuracy: 0.7994 - val_gender_adversary_output_accuracy: 0.2962 - val_loss: 3.7505 - val_main_output_accuracy: 0.8921 - val_race_adversary_output_accuracy: 0.0325
# Epoch 7/50
# 13245/13245 ━━━━━━━━━━━━━━━━━━━━ 613s 46ms/step - ethnicity_adversary_output_accuracy: 0.5308 - gender_adversary_output_accuracy: 0.3669 - loss: 2.1021 - main_output_accuracy: 0.8566 - race_adversary_output_accuracy: 0.5727 - val_ethnicity_adversary_output_accuracy: 0.7994 - val_gender_adversary_output_accuracy: 0.2937 - val_loss: 3.7959 - val_main_output_accuracy: 0.8922 - val_race_adversary_output_accuracy: 0.0325

# %%
########################################
# Evaluation on Test Set
########################################

test_predictions = combined_model.predict(X_test_scaled)
main_test_predictions_prob = test_predictions[0].reshape(-1)
main_test_predictions = (main_test_predictions_prob >= 0.5).astype(int)

def evaluate_model(y_true, y_pred, model_name):
    print(f"\n### {model_name} Performance ###")
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (TPR): {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")
    print("Confusion Matrix:")
    cm = confusion_matrix(y_true, y_pred)
    cm_df = pd.DataFrame(cm, index=['Actual Negative','Actual Positive'], columns=['Predicted Negative','Predicted Positive'])
    display(cm_df)

evaluate_model(y_test.values, main_test_predictions, "Adversarial Neural Network with Resampled Data")
# Out:
# 10015/10015 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step
#
# ### Adversarial Neural Network with Resampled Data Performance ###
# Accuracy: 0.8262
# Precision: 0.9357
# Recall (TPR): 0.7717
# F1-Score: 0.8458
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative              111987               10498
# Actual Positive               45209              152779

# %%
########################################
# Prepare final test_results with SES, Race, Gender, Ethnicity
########################################

import pandas as pd

# Set pandas to display all rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

test_results = pd.DataFrame(X_test_scaled, columns=feature_cols)
test_results['Actual'] = y_test.reset_index(drop=True)
test_results['Predicted'] = main_test_predictions

# Merge sensitive_test_simplified info
sensitive_test_simplified = sensitive_test_simplified.reset_index(drop=True)
test_results['Race'] = sensitive_test_simplified['race_group']
test_results['Gender'] = sensitive_test_simplified['gender_group']
test_results['Ethnicity'] = sensitive_test_simplified['ethnicity_group']

def categorize_ses(row):
    # Use tract_to_msa_income_percentage from scaled data:
    # We must revert scaling or use original df. Let's assume original logic:
    # If you want original data, re-merge from X_test. We can do this by inverse scaling or
    # since we know the threshold: <80 Low, <=120 Middle, else High
    # We'll trust that scaling didn't reorder data. We can just use original X_test.
    original_value = row['tract_to_msa_income_percentage']* (X_train['tract_to_msa_income_percentage'].max() - X_train['tract_to_msa_income_percentage'].min()) + X_train['tract_to_msa_income_percentage'].min()
    if original_value < 80:
        return 'Low'
    elif original_value <= 120:
        return 'Middle'
    else:
        return 'High'

# To apply SES categorization correctly, let's store original values before scaling:
# We'll just recategorize using original X_test directly:
X_test_reset = X_test.reset_index(drop=True)
test_results['original_tract_to_msa_income_percentage'] = X_test_reset['tract_to_msa_income_percentage'].values
test_results['SES'] = test_results['original_tract_to_msa_income_percentage'].apply(lambda v: 'Low' if v<80 else ('Middle' if v<=120 else 'High'))
test_results.drop('original_tract_to_msa_income_percentage', axis=1, inplace=True)

# %%
########################################
# Compute Fairness Metrics as Requested
########################################

# Functions to compute fairness metrics
def compute_approval_rate(df, group_cols):
    return df.groupby(group_cols)['Predicted'].mean()

def compute_statistical_parity(df, group_cols):
    # Same as approval rate
    return compute_approval_rate(df, group_cols)

def compute_predictive_parity(df, group_cols):
    metrics = {}
    for gvals, gdf in df.groupby(group_cols):
        precision = precision_score(gdf['Actual'], gdf['Predicted'], zero_division=0)
        metrics[gvals] = precision
    return pd.Series(metrics)

def compute_equal_opportunity(df, group_cols):
    metrics = {}
    for gvals, gdf in df.groupby(group_cols):
        recall = recall_score(gdf['Actual'], gdf['Predicted'], zero_division=0)
        metrics[gvals] = recall
    return pd.Series(metrics)

def compute_fpr_parity(df, group_cols):
    metrics = {}
    for gvals, gdf in df.groupby(group_cols):
        cm = confusion_matrix(gdf['Actual'], gdf['Predicted'], labels=[0,1])
        tn, fp, fn, tp = cm.ravel()
        fpr = fp / (fp + tn) if (fp+tn) > 0 else 0
        metrics[gvals] = fpr
    return pd.Series(metrics)

def compute_base_rate(df, group_cols):
    return df.groupby(group_cols)['Actual'].mean()

def compute_all_metrics(df, group_cols):
    approval = compute_approval_rate(df, group_cols)
    stat_parity = compute_statistical_parity(df, group_cols)
    pred_parity = compute_predictive_parity(df, group_cols)
    eq_opp = compute_equal_opportunity(df, group_cols)
    fpr = compute_fpr_parity(df, group_cols)
    base = compute_base_rate(df, group_cols)
    res = pd.DataFrame({
        'Approval Rate': approval,
        'Statistical Parity': stat_parity,
        'Predictive Parity': pred_parity,
        'Equal Opportunity': eq_opp,
        'FPR Parity': fpr,
        'Base Rate': base
    })
    return res

def format_table(df):
    for col in ['Approval Rate','Statistical Parity','Predictive Parity','Equal Opportunity','FPR Parity','Base Rate']:
        if col in df.columns:
            df[col] = df[col].apply(lambda x: f"{x:.2f}")
    return df

def split_multiindex(df, new_cols):
    df = df.reset_index()
    df.columns = list(new_cols) + list(df.columns[len(new_cols):])
    return df

# %%
########################################
# Full intersection: SES × Race × Gender × Ethnicity
########################################
full_metrics = compute_all_metrics(test_results, ['SES','Race','Gender','Ethnicity'])
full_table = split_multiindex(full_metrics, ['SES','Race','Gender','Ethnicity'])
full_table = format_table(full_table)

print("\n### Fairness Metrics by SES × Race × Gender × Ethnicity ###\n")
display(full_table)
# Out:
# ### Fairness Metrics by SES × Race × Gender × Ethnicity ###
#      SES                                       Race  \
# 0    Low           American Indian or Alaska Native
# 1    Low           American Indian or Alaska Native
# 2    Low           American Indian or Alaska Native
# 3    Low           American Indian or Alaska Native
# 4    Low           American Indian or Alaska Native
# 5    Low           American Indian or Alaska Native
# 6    Low           American Indian or Alaska Native
# 7    Low           American Indian or Alaska Native
# 8    Low           American Indian or Alaska Native
# 9    Low           American Indian or Alaska Native
# 10   Low           American Indian or Alaska Native
# 11   Low           American Indian or Alaska Native
# 12   Low           American Indian or Alaska Native
# 13   Low           American Indian or Alaska Native
# 14   Low           American Indian or Alaska Native
# 15   Low           American Indian or Alaska Native
# 16   Low           American Indian or Alaska Native
# 17   Low           American Indian or Alaska Native
# 18   Low                                      Asian
# 19   Low                                      Asian
# 20   Low                                      Asian
# 21   Low                                      Asian
# 22   Low                                      Asian
# 23   Low                                      Asian
# 24   Low                                      Asian
# 25   Low                                      Asian
# 26   Low                                      Asian
# 27   Low                                      Asian
# 28   Low                                      Asian
# 29   Low                                      Asian
# 30   Low                                      Asian
# 31   Low                                      Asian
# 32   Low                                      Asian
# 33   Low                                      Asian
# 34   Low                                      Asian
# 35   Low                                      Asian
# 36   Low                                      Asian
# 37   Low                  Black or African American
# 38   Low                  Black or African American
# 39   Low                  Black or African American
# 40   Low                  Black or African American
# 41   Low                  Black or African American
# 42   Low                  Black or African American
# 43   Low                  Black or African American
# 44   Low                  Black or African American
# 45   Low                  Black or African American
# 46   Low                  Black or African American
# 47   Low                  Black or African American
# 48   Low                  Black or African American
# 49   Low                  Black or African American
# 50   Low                  Black or African American
# 51   Low                  Black or African American
# 52   Low                  Black or African American
# 53   Low                  Black or African American
# 54   Low                  Black or African American
# 55   Low                  Black or African American
# 56   Low  Native Hawaiian or Other Pacific Islander
# 57   Low  Native Hawaiian or Other Pacific Islander
# 58   Low  Native Hawaiian or Other Pacific Islander
# 59   Low  Native Hawaiian or Other Pacific Islander
# 60   Low  Native Hawaiian or Other Pacific Islander
# 61   Low  Native Hawaiian or Other Pacific Islander
# 62   Low  Native Hawaiian or Other Pacific Islander
# 63   Low  Native Hawaiian or Other Pacific Islander
# 64   Low  Native Hawaiian or Other Pacific Islander
# 65   Low  Native Hawaiian or Other Pacific Islander
# 66   Low  Native Hawaiian or Other Pacific Islander
# 67   Low  Native Hawaiian or Other Pacific Islander
# 68   Low  Native Hawaiian or Other Pacific Islander
# 69   Low  Native Hawaiian or Other Pacific Islander
# 70   Low  Native Hawaiian or Other Pacific Islander
# 71   Low  Native Hawaiian or Other Pacific Islander
# 72   Low                                      Other
# 73   Low                                      Other
# 74   Low                                      Other
# 75   Low                                      Other
# 76   Low                                      Other
# 77   Low                                      Other
# 78   Low                                      Other
# 79   Low                                      Other
# 80   Low                                      Other
# 81   Low                                      Other
# 82   Low                                      Other
# 83   Low                                      Other
# 84   Low                                      Other
# 85   Low                                      Other
# 86   Low                                      Other
# 87   Low                                      Other
# 88   Low                                      Other
# 89   Low                                      Other
# 90   Low                                      Other
# 91   Low                                      Other
# 92   Low                  Unknown or Not Applicable
# 93   Low                  Unknown or Not Applicable
# 94   Low                  Unknown or Not Applicable
# 95   Low                  Unknown or Not Applicable
# 96   Low                  Unknown or Not Applicable
# 97   Low                  Unknown or Not Applicable
# 98   Low                  Unknown or Not Applicable
# 99   Low                  Unknown or Not Applicable
# 100  Low                  Unknown or Not Applicable
# 101  Low                  Unknown or Not Applicable
# 102  Low                  Unknown or Not Applicable
# 103  Low                  Unknown or Not Applicable
# 104  Low                  Unknown or Not Applicable
# 105  Low                  Unknown or Not Applicable
# 106  Low                  Unknown or Not Applicable
# 107  Low                  Unknown or Not Applicable
# 108  Low                  Unknown or Not Applicable
# 109  Low                  Unknown or Not Applicable
# 110  Low                  Unknown or Not Applicable
# 111  Low                                      White
# 112  Low                                      White
# 113  Low                                      White
# 114  Low                                      White
# 115  Low                                      White
# 116  Low                                      White
# 117  Low                                      White
# 118  Low                                      White
# 119  Low                                      White
# 120  Low                                      White
# 121  Low                                      White
# 122  Low                                      White
# 123  Low                                      White
# 124  Low                                      White
# 125  Low                                      White
# 126  Low                                      White
# 127  Low                                      White
# 128  Low                                      White
# 129  Low                                      White
#
#                         Gender                  Ethnicity Approval Rate  \
# 0                       Female         Hispanic or Latino          0.34
# 1                       Female                      Joint          0.08
# 2                       Female     Not Hispanic or Latino          0.41
# 3                       Female                      Other          0.26
# 4                       Female  Unknown or Not Applicable          0.00
# 5                        Joint         Hispanic or Latino          0.38
# 6                        Joint                      Joint          0.51
# 7                        Joint     Not Hispanic or Latino          0.43
# 8                        Joint                      Other          0.50
# 9                        Joint  Unknown or Not Applicable          0.00
# 10                        Male         Hispanic or Latino          0.32
# 11                        Male                      Joint          0.05
# 12                        Male     Not Hispanic or Latino          0.37
# 13                        Male                      Other          0.42
# 14   Unknown or Not Applicable         Hispanic or Latino          0.40
# 15   Unknown or Not Applicable                      Joint          0.00
# 16   Unknown or Not Applicable     Not Hispanic or Latino          0.00
# 17   Unknown or Not Applicable                      Other          0.21
# 18                      Female         Hispanic or Latino          0.40
# 19                      Female                      Joint          0.46
# 20                      Female     Not Hispanic or Latino          0.45
# 21                      Female                      Other          0.43
# 22                      Female  Unknown or Not Applicable          0.17
# 23                       Joint         Hispanic or Latino          0.39
# 24                       Joint                      Joint          0.55
# 25                       Joint     Not Hispanic or Latino          0.53
# 26                       Joint                      Other          0.47
# 27                       Joint  Unknown or Not Applicable          0.44
# 28                        Male         Hispanic or Latino          0.36
# 29                        Male                      Joint          0.40
# 30                        Male     Not Hispanic or Latino          0.46
# 31                        Male                      Other          0.40
# 32                        Male  Unknown or Not Applicable          0.31
# 33   Unknown or Not Applicable         Hispanic or Latino          0.38
# 34   Unknown or Not Applicable                      Joint          0.33
# 35   Unknown or Not Applicable     Not Hispanic or Latino          0.36
# 36   Unknown or Not Applicable                      Other          0.45
# 37                      Female         Hispanic or Latino          0.44
# 38                      Female                      Joint          0.43
# 39                      Female     Not Hispanic or Latino          0.39
# 40                      Female                      Other          0.41
# 41                      Female  Unknown or Not Applicable          0.12
# 42                       Joint         Hispanic or Latino          0.38
# 43                       Joint                      Joint          0.47
# 44                       Joint     Not Hispanic or Latino          0.42
# 45                       Joint                      Other          0.35
# 46                       Joint  Unknown or Not Applicable          0.33
# 47                        Male         Hispanic or Latino          0.35
# 48                        Male                      Joint          0.33
# 49                        Male     Not Hispanic or Latino          0.36
# 50                        Male                      Other          0.30
# 51                        Male  Unknown or Not Applicable          0.57
# 52   Unknown or Not Applicable         Hispanic or Latino          0.55
# 53   Unknown or Not Applicable                      Joint          0.33
# 54   Unknown or Not Applicable     Not Hispanic or Latino          0.17
# 55   Unknown or Not Applicable                      Other          0.43
# 56                      Female         Hispanic or Latino          0.21
# 57                      Female                      Joint          0.20
# 58                      Female     Not Hispanic or Latino          0.35
# 59                      Female                      Other          0.29
# 60                       Joint         Hispanic or Latino          0.34
# 61                       Joint                      Joint          0.32
# 62                       Joint     Not Hispanic or Latino          0.40
# 63                       Joint                      Other          0.33
# 64                        Male         Hispanic or Latino          0.32
# 65                        Male                      Joint          0.00
# 66                        Male     Not Hispanic or Latino          0.38
# 67                        Male                      Other          0.45
# 68                        Male  Unknown or Not Applicable          0.50
# 69   Unknown or Not Applicable         Hispanic or Latino          0.00
# 70   Unknown or Not Applicable     Not Hispanic or Latino          0.12
# 71   Unknown or Not Applicable                      Other          0.93
# 72                      Female         Hispanic or Latino          0.29
# 73                      Female                      Joint          0.47
# 74                      Female     Not Hispanic or Latino          0.47
# 75                      Female                      Other          0.45
# 76                      Female  Unknown or Not Applicable          0.71
# 77                       Joint         Hispanic or Latino          0.47
# 78                       Joint                      Joint          0.51
# 79                       Joint     Not Hispanic or Latino          0.53
# 80                       Joint                      Other          0.48
# 81                       Joint  Unknown or Not Applicable          0.42
# 82                        Male         Hispanic or Latino          0.25
# 83                        Male                      Joint          0.35
# 84                        Male     Not Hispanic or Latino          0.49
# 85                        Male                      Other          0.40
# 86                        Male  Unknown or Not Applicable          0.27
# 87   Unknown or Not Applicable         Hispanic or Latino          0.50
# 88   Unknown or Not Applicable                      Joint          0.00
# 89   Unknown or Not Applicable     Not Hispanic or Latino          0.52
# 90   Unknown or Not Applicable                      Other          0.36
# 91   Unknown or Not Applicable  Unknown or Not Applicable          0.56
# 92                      Female         Hispanic or Latino          0.32
# 93                      Female                      Joint          0.39
# 94                      Female     Not Hispanic or Latino          0.40
# 95                      Female                      Other          0.40
# 96                      Female  Unknown or Not Applicable          0.25
# 97                       Joint         Hispanic or Latino          0.40
# 98                       Joint                      Joint          0.49
# 99                       Joint     Not Hispanic or Latino          0.50
# 100                      Joint                      Other          0.50
# 101                      Joint  Unknown or Not Applicable          0.20
# 102                       Male         Hispanic or Latino          0.33
# 103                       Male                      Joint          0.44
# 104                       Male     Not Hispanic or Latino          0.40
# 105                       Male                      Other          0.42
# 106                       Male  Unknown or Not Applicable          0.55
# 107  Unknown or Not Applicable         Hispanic or Latino          0.39
# 108  Unknown or Not Applicable                      Joint          0.50
# 109  Unknown or Not Applicable     Not Hispanic or Latino          0.51
# 110  Unknown or Not Applicable                      Other          0.69
# 111                     Female         Hispanic or Latino          0.41
# 112                     Female                      Joint          0.44
# 113                     Female     Not Hispanic or Latino          0.46
# 114                     Female                      Other          0.42
# 115                     Female  Unknown or Not Applicable          0.27
# 116                      Joint         Hispanic or Latino          0.47
# 117                      Joint                      Joint          0.52
# 118                      Joint     Not Hispanic or Latino          0.53
# 119                      Joint                      Other          0.48
# 120                      Joint  Unknown or Not Applicable          0.48
# 121                       Male         Hispanic or Latino          0.42
# 122                       Male                      Joint          0.45
# 123                       Male     Not Hispanic or Latino          0.46
# 124                       Male                      Other          0.43
# 125                       Male  Unknown or Not Applicable          0.39
# 126  Unknown or Not Applicable         Hispanic or Latino          0.19
# 127  Unknown or Not Applicable                      Joint          0.54
# 128  Unknown or Not Applicable     Not Hispanic or Latino          0.26
# 129  Unknown or Not Applicable                      Other          0.38
#
#     Statistical Parity Predictive Parity Equal Opportunity FPR Parity  \
# 0                 0.34              0.91              0.73       0.05
# 1                 0.08              1.00              0.50       0.00
# 2                 0.41              0.92              0.68       0.07
# 3                 0.26              0.75              0.86       0.08
# 4                 0.00              0.00              0.00       0.00
# 5                 0.38              0.93              0.70       0.05
# 6                 0.51              0.92              0.79       0.10
# 7                 0.43              0.92              0.72       0.07
# 8                 0.50              1.00              0.75       0.00
# 9                 0.00              0.00              0.00       0.00
# 10                0.32              0.89              0.75       0.06
# 11                0.05              1.00              0.50       0.00
# 12                0.37              0.90              0.76       0.07
# 13                0.42              0.90              0.87       0.08
# 14                0.40              1.00              1.00       0.00
# 15                0.00              0.00              0.00       0.00
# 16                0.00              0.00              0.00       0.00
# 17                0.21              1.00              0.80       0.00
# 18                0.40              0.90              0.78       0.07
# 19                0.46              0.91              0.87       0.08
# 20                0.45              0.92              0.75       0.08
# 21                0.43              0.95              0.80       0.05
# 22                0.17              1.00              1.00       0.00
# 23                0.39              0.97              0.77       0.02
# 24                0.55              0.93              0.82       0.10
# 25                0.53              0.94              0.80       0.08
# 26                0.47              0.94              0.78       0.07
# 27                0.44              1.00              0.89       0.00
# 28                0.36              0.89              0.78       0.07
# 29                0.40              0.90              0.85       0.07
# 30                0.46              0.91              0.79       0.08
# 31                0.40              0.90              0.78       0.08
# 32                0.31              1.00              1.00       0.00
# 33                0.38              0.67              0.50       0.25
# 34                0.33              1.00              1.00       0.00
# 35                0.36              0.97              0.83       0.02
# 36                0.45              0.94              0.87       0.05
# 37                0.44              0.86              0.81       0.12
# 38                0.43              0.90              0.90       0.07
# 39                0.39              0.89              0.72       0.08
# 40                0.41              0.87              0.71       0.11
# 41                0.12              1.00              0.50       0.00
# 42                0.38              0.96              0.71       0.03
# 43                0.47              0.95              0.77       0.05
# 44                0.42              0.93              0.71       0.07
# 45                0.35              0.88              0.70       0.08
# 46                0.33              1.00              1.00       0.00
# 47                0.35              0.91              0.78       0.06
# 48                0.33              1.00              0.83       0.00
# 49                0.36              0.89              0.73       0.07
# 50                0.30              0.93              0.79       0.03
# 51                0.57              1.00              1.00       0.00
# 52                0.55              1.00              0.86       0.00
# 53                0.33              0.00              0.00       1.00
# 54                0.17              0.95              0.81       0.01
# 55                0.43              1.00              0.88       0.00
# 56                0.21              0.88              0.67       0.04
# 57                0.20              1.00              1.00       0.00
# 58                0.35              0.87              0.73       0.07
# 59                0.29              1.00              0.56       0.00
# 60                0.34              1.00              0.77       0.00
# 61                0.32              0.88              0.58       0.08
# 62                0.40              0.95              0.75       0.04
# 63                0.33              1.00              0.71       0.00
# 64                0.32              0.84              0.80       0.08
# 65                0.00              0.00              0.00       0.00
# 66                0.38              0.92              0.76       0.05
# 67                0.45              1.00              0.71       0.00
# 68                0.50              0.00              0.00       0.50
# 69                0.00              0.00              0.00       0.00
# 70                0.12              1.00              1.00       0.00
# 71                0.93              1.00              1.00       0.00
# 72                0.29              0.96              0.68       0.02
# 73                0.47              0.90              0.82       0.09
# 74                0.47              0.90              0.78       0.10
# 75                0.45              1.00              0.75       0.00
# 76                0.71              1.00              0.83       0.00
# 77                0.47              0.93              0.77       0.07
# 78                0.51              0.93              0.77       0.10
# 79                0.53              0.93              0.78       0.10
# 80                0.48              0.90              0.73       0.12
# 81                0.42              0.62              0.45       0.38
# 82                0.25              0.84              0.65       0.06
# 83                0.35              0.89              0.76       0.07
# 84                0.49              0.91              0.77       0.10
# 85                0.40              0.79              0.79       0.14
# 86                0.27              1.00              0.57       0.00
# 87                0.50              1.00              1.00       0.00
# 88                0.00              0.00              0.00       0.00
# 89                0.52              1.00              0.78       0.00
# 90                0.36              1.00              0.80       0.00
# 91                0.56              0.89              0.73       0.20
# 92                0.32              0.89              0.72       0.06
# 93                0.39              0.94              0.80       0.04
# 94                0.40              0.89              0.75       0.08
# 95                0.40              0.90              0.73       0.08
# 96                0.25              1.00              1.00       0.00
# 97                0.40              0.91              0.73       0.07
# 98                0.49              0.92              0.79       0.09
# 99                0.50              0.93              0.78       0.09
# 100               0.50              0.93              0.76       0.10
# 101               0.20              1.00              0.33       0.00
# 102               0.33              0.90              0.74       0.06
# 103               0.44              0.93              0.89       0.06
# 104               0.40              0.90              0.78       0.08
# 105               0.42              0.89              0.76       0.09
# 106               0.55              0.83              1.00       0.17
# 107               0.39              0.96              0.82       0.03
# 108               0.50              1.00              1.00       0.00
# 109               0.51              0.93              0.83       0.09
# 110               0.69              0.98              0.83       0.08
# 111               0.41              0.91              0.73       0.07
# 112               0.44              0.92              0.74       0.08
# 113               0.46              0.91              0.73       0.10
# 114               0.42              0.90              0.74       0.09
# 115               0.27              0.88              0.58       0.06
# 116               0.47              0.93              0.72       0.08
# 117               0.52              0.93              0.75       0.10
# 118               0.53              0.94              0.74       0.10
# 119               0.48              0.92              0.73       0.10
# 120               0.48              0.96              0.70       0.06
# 121               0.42              0.91              0.75       0.08
# 122               0.45              0.91              0.77       0.09
# 123               0.46              0.91              0.75       0.10
# 124               0.43              0.88              0.77       0.10
# 125               0.39              0.92              0.79       0.06
# 126               0.19              0.93              0.81       0.02
# 127               0.54              1.00              0.70       0.00
# 128               0.26              0.91              0.77       0.04
# 129               0.38              0.90              0.69       0.07
#
#     Base Rate
# 0        0.42
# 1        0.15
# 2        0.56
# 3        0.23
# 4        0.00
# 5        0.50
# 6        0.59
# 7        0.55
# 8        0.67
# 9        0.00
# 10       0.38
# 11       0.10
# 12       0.43
# 13       0.43
# 14       0.40
# 15       1.00
# 16       0.00
# 17       0.26
# 18       0.47
# 19       0.48
# 20       0.55
# 21       0.50
# 22       0.17
# 23       0.50
# 24       0.62
# 25       0.62
# 26       0.57
# 27       0.50
# 28       0.41
# 29       0.42
# 30       0.53
# 31       0.46
# 32       0.31
# 33       0.50
# 34       0.33
# 35       0.42
# 36       0.49
# 37       0.47
# 38       0.43
# 39       0.48
# 40       0.50
# 41       0.25
# 42       0.51
# 43       0.59
# 44       0.55
# 45       0.44
# 46       0.33
# 47       0.41
# 48       0.40
# 49       0.45
# 50       0.35
# 51       0.57
# 52       0.64
# 53       0.67
# 54       0.20
# 55       0.49
# 56       0.28
# 57       0.20
# 58       0.41
# 59       0.53
# 60       0.44
# 61       0.48
# 62       0.51
# 63       0.47
# 64       0.33
# 65       0.00
# 66       0.46
# 67       0.64
# 68       0.00
# 69       0.75
# 70       0.12
# 71       0.93
# 72       0.41
# 73       0.52
# 74       0.54
# 75       0.60
# 76       0.86
# 77       0.57
# 78       0.61
# 79       0.64
# 80       0.60
# 81       0.58
# 82       0.33
# 83       0.42
# 84       0.58
# 85       0.40
# 86       0.47
# 87       0.50
# 88       0.00
# 89       0.67
# 90       0.45
# 91       0.69
# 92       0.40
# 93       0.45
# 94       0.47
# 95       0.50
# 96       0.25
# 97       0.50
# 98       0.57
# 99       0.59
# 100      0.61
# 101      0.60
# 102      0.40
# 103      0.45
# 104      0.46
# 105      0.49
# 106      0.45
# 107      0.45
# 108      0.50
# 109      0.57
# 110      0.82
# 111      0.51
# 112      0.54
# 113      0.58
# 114      0.52
# 115      0.40
# 116      0.60
# 117      0.65
# 118      0.67
# 119      0.61
# 120      0.66
# 121      0.51
# 122      0.53
# 123      0.55
# 124      0.49
# 125      0.46
# 126      0.22
# 127      0.77
# 128      0.31
# 129      0.49

# %%
########################################
# Non-SES intersection: Race × Gender × Ethnicity
########################################
non_ses_metrics = compute_all_metrics(test_results, ['Race','Gender','Ethnicity'])
non_ses_table = split_multiindex(non_ses_metrics, ['Race','Gender','Ethnicity'])
non_ses_table = format_table(non_ses_table)

print("\n### Fairness Metrics by Race × Gender × Ethnicity ###\n")
display(non_ses_table)

print("All requested tables have been displayed.")
# Out:
# ### Fairness Metrics by Race × Gender × Ethnicity ###
#                                           Race                     Gender  \
# 0             American Indian or Alaska Native                     Female
# 1             American Indian or Alaska Native                     Female
# 2             American Indian or Alaska Native                     Female
# 3             American Indian or Alaska Native                     Female
# 4             American Indian or Alaska Native                     Female
# 5             American Indian or Alaska Native                      Joint
# 6             American Indian or Alaska Native                      Joint
# 7             American Indian or Alaska Native                      Joint
# 8             American Indian or Alaska Native                      Joint
# 9             American Indian or Alaska Native                      Joint
# 10            American Indian or Alaska Native                       Male
# 11            American Indian or Alaska Native                       Male
# 12            American Indian or Alaska Native                       Male
# 13            American Indian or Alaska Native                       Male
# 14            American Indian or Alaska Native  Unknown or Not Applicable
# 15            American Indian or Alaska Native  Unknown or Not Applicable
# 16            American Indian or Alaska Native  Unknown or Not Applicable
# 17            American Indian or Alaska Native  Unknown or Not Applicable
# 18                                       Asian                     Female
# 19                                       Asian                     Female
# 20                                       Asian                     Female
# 21                                       Asian                     Female
# 22                                       Asian                     Female
# 23                                       Asian                      Joint
# 24                                       Asian                      Joint
# 25                                       Asian                      Joint
# 26                                       Asian                      Joint
# 27                                       Asian                      Joint
# 28                                       Asian                       Male
# 29                                       Asian                       Male
# 30                                       Asian                       Male
# 31                                       Asian                       Male
# 32                                       Asian                       Male
# 33                                       Asian  Unknown or Not Applicable
# 34                                       Asian  Unknown or Not Applicable
# 35                                       Asian  Unknown or Not Applicable
# 36                                       Asian  Unknown or Not Applicable
# 37                   Black or African American                     Female
# 38                   Black or African American                     Female
# 39                   Black or African American                     Female
# 40                   Black or African American                     Female
# 41                   Black or African American                     Female
# 42                   Black or African American                      Joint
# 43                   Black or African American                      Joint
# 44                   Black or African American                      Joint
# 45                   Black or African American                      Joint
# 46                   Black or African American                      Joint
# 47                   Black or African American                       Male
# 48                   Black or African American                       Male
# 49                   Black or African American                       Male
# 50                   Black or African American                       Male
# 51                   Black or African American                       Male
# 52                   Black or African American  Unknown or Not Applicable
# 53                   Black or African American  Unknown or Not Applicable
# 54                   Black or African American  Unknown or Not Applicable
# 55                   Black or African American  Unknown or Not Applicable
# 56   Native Hawaiian or Other Pacific Islander                     Female
# 57   Native Hawaiian or Other Pacific Islander                     Female
# 58   Native Hawaiian or Other Pacific Islander                     Female
# 59   Native Hawaiian or Other Pacific Islander                     Female
# 60   Native Hawaiian or Other Pacific Islander                      Joint
# 61   Native Hawaiian or Other Pacific Islander                      Joint
# 62   Native Hawaiian or Other Pacific Islander                      Joint
# 63   Native Hawaiian or Other Pacific Islander                      Joint
# 64   Native Hawaiian or Other Pacific Islander                       Male
# 65   Native Hawaiian or Other Pacific Islander                       Male
# 66   Native Hawaiian or Other Pacific Islander                       Male
# 67   Native Hawaiian or Other Pacific Islander                       Male
# 68   Native Hawaiian or Other Pacific Islander                       Male
# 69   Native Hawaiian or Other Pacific Islander  Unknown or Not Applicable
# 70   Native Hawaiian or Other Pacific Islander  Unknown or Not Applicable
# 71   Native Hawaiian or Other Pacific Islander  Unknown or Not Applicable
# 72                                       Other                     Female
# 73                                       Other                     Female
# 74                                       Other                     Female
# 75                                       Other                     Female
# 76                                       Other                     Female
# 77                                       Other                      Joint
# 78                                       Other                      Joint
# 79                                       Other                      Joint
# 80                                       Other                      Joint
# 81                                       Other                      Joint
# 82                                       Other                       Male
# 83                                       Other                       Male
# 84                                       Other                       Male
# 85                                       Other                       Male
# 86                                       Other                       Male
# 87                                       Other  Unknown or Not Applicable
# 88                                       Other  Unknown or Not Applicable
# 89                                       Other  Unknown or Not Applicable
# 90                                       Other  Unknown or Not Applicable
# 91                                       Other  Unknown or Not Applicable
# 92                   Unknown or Not Applicable                     Female
# 93                   Unknown or Not Applicable                     Female
# 94                   Unknown or Not Applicable                     Female
# 95                   Unknown or Not Applicable                     Female
# 96                   Unknown or Not Applicable                     Female
# 97                   Unknown or Not Applicable                      Joint
# 98                   Unknown or Not Applicable                      Joint
# 99                   Unknown or Not Applicable                      Joint
# 100                  Unknown or Not Applicable                      Joint
# 101                  Unknown or Not Applicable                      Joint
# 102                  Unknown or Not Applicable                       Male
# 103                  Unknown or Not Applicable                       Male
# 104                  Unknown or Not Applicable                       Male
# 105                  Unknown or Not Applicable                       Male
# 106                  Unknown or Not Applicable                       Male
# 107                  Unknown or Not Applicable  Unknown or Not Applicable
# 108                  Unknown or Not Applicable  Unknown or Not Applicable
# 109                  Unknown or Not Applicable  Unknown or Not Applicable
# 110                  Unknown or Not Applicable  Unknown or Not Applicable
# 111                                      White                     Female
# 112                                      White                     Female
# 113                                      White                     Female
# 114                                      White                     Female
# 115                                      White                     Female
# 116                                      White                      Joint
# 117                                      White                      Joint
# 118                                      White                      Joint
# 119                                      White                      Joint
# 120                                      White                      Joint
# 121                                      White                       Male
# 122                                      White                       Male
# 123                                      White                       Male
# 124                                      White                       Male
# 125                                      White                       Male
# 126                                      White  Unknown or Not Applicable
# 127                                      White  Unknown or Not Applicable
# 128                                      White  Unknown or Not Applicable
# 129                                      White  Unknown or Not Applicable
#
#                      Ethnicity Approval Rate Statistical Parity  \
# 0           Hispanic or Latino          0.34               0.34
# 1                        Joint          0.08               0.08
# 2       Not Hispanic or Latino          0.41               0.41
# 3                        Other          0.26               0.26
# 4    Unknown or Not Applicable          0.00               0.00
# 5           Hispanic or Latino          0.38               0.38
# 6                        Joint          0.51               0.51
# 7       Not Hispanic or Latino          0.43               0.43
# 8                        Other          0.50               0.50
# 9    Unknown or Not Applicable          0.00               0.00
# 10          Hispanic or Latino          0.32               0.32
# 11                       Joint          0.05               0.05
# 12      Not Hispanic or Latino          0.37               0.37
# 13                       Other          0.42               0.42
# 14          Hispanic or Latino          0.40               0.40
# 15                       Joint          0.00               0.00
# 16      Not Hispanic or Latino          0.00               0.00
# 17                       Other          0.21               0.21
# 18          Hispanic or Latino          0.40               0.40
# 19                       Joint          0.46               0.46
# 20      Not Hispanic or Latino          0.45               0.45
# 21                       Other          0.43               0.43
# 22   Unknown or Not Applicable          0.17               0.17
# 23          Hispanic or Latino          0.39               0.39
# 24                       Joint          0.55               0.55
# 25      Not Hispanic or Latino          0.53               0.53
# 26                       Other          0.47               0.47
# 27   Unknown or Not Applicable          0.44               0.44
# 28          Hispanic or Latino          0.36               0.36
# 29                       Joint          0.40               0.40
# 30      Not Hispanic or Latino          0.46               0.46
# 31                       Other          0.40               0.40
# 32   Unknown or Not Applicable          0.31               0.31
# 33          Hispanic or Latino          0.38               0.38
# 34                       Joint          0.33               0.33
# 35      Not Hispanic or Latino          0.36               0.36
# 36                       Other          0.45               0.45
# 37          Hispanic or Latino          0.44               0.44
# 38                       Joint          0.43               0.43
# 39      Not Hispanic or Latino          0.39               0.39
# 40                       Other          0.41               0.41
# 41   Unknown or Not Applicable          0.12               0.12
# 42          Hispanic or Latino          0.38               0.38
# 43                       Joint          0.47               0.47
# 44      Not Hispanic or Latino          0.42               0.42
# 45                       Other          0.35               0.35
# 46   Unknown or Not Applicable          0.33               0.33
# 47          Hispanic or Latino          0.35               0.35
# 48                       Joint          0.33               0.33
# 49      Not Hispanic or Latino          0.36               0.36
# 50                       Other          0.30               0.30
# 51   Unknown or Not Applicable          0.57               0.57
# 52          Hispanic or Latino          0.55               0.55
# 53                       Joint          0.33               0.33
# 54      Not Hispanic or Latino          0.17               0.17
# 55                       Other          0.43               0.43
# 56          Hispanic or Latino          0.21               0.21
# 57                       Joint          0.20               0.20
# 58      Not Hispanic or Latino          0.35               0.35
# 59                       Other          0.29               0.29
# 60          Hispanic or Latino          0.34               0.34
# 61                       Joint          0.32               0.32
# 62      Not Hispanic or Latino          0.40               0.40
# 63                       Other          0.33               0.33
# 64          Hispanic or Latino          0.32               0.32
# 65                       Joint          0.00               0.00
# 66      Not Hispanic or Latino          0.38               0.38
# 67                       Other          0.45               0.45
# 68   Unknown or Not Applicable          0.50               0.50
# 69          Hispanic or Latino          0.00               0.00
# 70      Not Hispanic or Latino          0.12               0.12
# 71                       Other          0.93               0.93
# 72          Hispanic or Latino          0.29               0.29
# 73                       Joint          0.47               0.47
# 74      Not Hispanic or Latino          0.47               0.47
# 75                       Other          0.45               0.45
# 76   Unknown or Not Applicable          0.71               0.71
# 77          Hispanic or Latino          0.47               0.47
# 78                       Joint          0.51               0.51
# 79      Not Hispanic or Latino          0.53               0.53
# 80                       Other          0.48               0.48
# 81   Unknown or Not Applicable          0.42               0.42
# 82          Hispanic or Latino          0.25               0.25
# 83                       Joint          0.35               0.35
# 84      Not Hispanic or Latino          0.49               0.49
# 85                       Other          0.40               0.40
# 86   Unknown or Not Applicable          0.27               0.27
# 87          Hispanic or Latino          0.50               0.50
# 88                       Joint          0.00               0.00
# 89      Not Hispanic or Latino          0.52               0.52
# 90                       Other          0.36               0.36
# 91   Unknown or Not Applicable          0.56               0.56
# 92          Hispanic or Latino          0.32               0.32
# 93                       Joint          0.39               0.39
# 94      Not Hispanic or Latino          0.40               0.40
# 95                       Other          0.40               0.40
# 96   Unknown or Not Applicable          0.25               0.25
# 97          Hispanic or Latino          0.40               0.40
# 98                       Joint          0.49               0.49
# 99      Not Hispanic or Latino          0.50               0.50
# 100                      Other          0.50               0.50
# 101  Unknown or Not Applicable          0.20               0.20
# 102         Hispanic or Latino          0.33               0.33
# 103                      Joint          0.44               0.44
# 104     Not Hispanic or Latino          0.40               0.40
# 105                      Other          0.42               0.42
# 106  Unknown or Not Applicable          0.55               0.55
# 107         Hispanic or Latino          0.39               0.39
# 108                      Joint          0.50               0.50
# 109     Not Hispanic or Latino          0.51               0.51
# 110                      Other          0.69               0.69
# 111         Hispanic or Latino          0.41               0.41
# 112                      Joint          0.44               0.44
# 113     Not Hispanic or Latino          0.46               0.46
# 114                      Other          0.42               0.42
# 115  Unknown or Not Applicable          0.27               0.27
# 116         Hispanic or Latino          0.47               0.47
# 117                      Joint          0.52               0.52
# 118     Not Hispanic or Latino          0.53               0.53
# 119                      Other          0.48               0.48
# 120  Unknown or Not Applicable          0.48               0.48
# 121         Hispanic or Latino          0.42               0.42
# 122                      Joint          0.45               0.45
# 123     Not Hispanic or Latino          0.46               0.46
# 124                      Other          0.43               0.43
# 125  Unknown or Not Applicable          0.39               0.39
# 126         Hispanic or Latino          0.19               0.19
# 127                      Joint          0.54               0.54
# 128     Not Hispanic or Latino          0.26               0.26
# 129                      Other          0.38               0.38
#
#     Predictive Parity Equal Opportunity FPR Parity Base Rate
# 0                0.91              0.73       0.05      0.42
# 1                1.00              0.50       0.00      0.15
# 2                0.92              0.68       0.07      0.56
# 3                0.75              0.86       0.08      0.23
# 4                0.00              0.00       0.00      0.00
# 5                0.93              0.70       0.05      0.50
# 6                0.92              0.79       0.10      0.59
# 7                0.92              0.72       0.07      0.55
# 8                1.00              0.75       0.00      0.67
# 9                0.00              0.00       0.00      0.00
# 10               0.89              0.75       0.06      0.38
# 11               1.00              0.50       0.00      0.10
# 12               0.90              0.76       0.07      0.43
# 13               0.90              0.87       0.08      0.43
# 14               1.00              1.00       0.00      0.40
# 15               0.00              0.00       0.00      1.00
# 16               0.00              0.00       0.00      0.00
# 17               1.00              0.80       0.00      0.26
# 18               0.90              0.78       0.07      0.47
# 19               0.91              0.87       0.08      0.48
# 20               0.92              0.75       0.08      0.55
# 21               0.95              0.80       0.05      0.50
# 22               1.00              1.00       0.00      0.17
# 23               0.97              0.77       0.02      0.50
# 24               0.93              0.82       0.10      0.62
# 25               0.94              0.80       0.08      0.62
# 26               0.94              0.78       0.07      0.57
# 27               1.00              0.89       0.00      0.50
# 28               0.89              0.78       0.07      0.41
# 29               0.90              0.85       0.07      0.42
# 30               0.91              0.79       0.08      0.53
# 31               0.90              0.78       0.08      0.46
# 32               1.00              1.00       0.00      0.31
# 33               0.67              0.50       0.25      0.50
# 34               1.00              1.00       0.00      0.33
# 35               0.97              0.83       0.02      0.42
# 36               0.94              0.87       0.05      0.49
# 37               0.86              0.81       0.12      0.47
# 38               0.90              0.90       0.07      0.43
# 39               0.89              0.72       0.08      0.48
# 40               0.87              0.71       0.11      0.50
# 41               1.00              0.50       0.00      0.25
# 42               0.96              0.71       0.03      0.51
# 43               0.95              0.77       0.05      0.59
# 44               0.93              0.71       0.07      0.55
# 45               0.88              0.70       0.08      0.44
# 46               1.00              1.00       0.00      0.33
# 47               0.91              0.78       0.06      0.41
# 48               1.00              0.83       0.00      0.40
# 49               0.89              0.73       0.07      0.45
# 50               0.93              0.79       0.03      0.35
# 51               1.00              1.00       0.00      0.57
# 52               1.00              0.86       0.00      0.64
# 53               0.00              0.00       1.00      0.67
# 54               0.95              0.81       0.01      0.20
# 55               1.00              0.88       0.00      0.49
# 56               0.88              0.67       0.04      0.28
# 57               1.00              1.00       0.00      0.20
# 58               0.87              0.73       0.07      0.41
# 59               1.00              0.56       0.00      0.53
# 60               1.00              0.77       0.00      0.44
# 61               0.88              0.58       0.08      0.48
# 62               0.95              0.75       0.04      0.51
# 63               1.00              0.71       0.00      0.47
# 64               0.84              0.80       0.08      0.33
# 65               0.00              0.00       0.00      0.00
# 66               0.92              0.76       0.05      0.46
# 67               1.00              0.71       0.00      0.64
# 68               0.00              0.00       0.50      0.00
# 69               0.00              0.00       0.00      0.75
# 70               1.00              1.00       0.00      0.12
# 71               1.00              1.00       0.00      0.93
# 72               0.96              0.68       0.02      0.41
# 73               0.90              0.82       0.09      0.52
# 74               0.90              0.78       0.10      0.54
# 75               1.00              0.75       0.00      0.60
# 76               1.00              0.83       0.00      0.86
# 77               0.93              0.77       0.07      0.57
# 78               0.93              0.77       0.10      0.61
# 79               0.93              0.78       0.10      0.64
# 80               0.90              0.73       0.12      0.60
# 81               0.62              0.45       0.38      0.58
# 82               0.84              0.65       0.06      0.33
# 83               0.89              0.76       0.07      0.42
# 84               0.91              0.77       0.10      0.58
# 85               0.79              0.79       0.14      0.40
# 86               1.00              0.57       0.00      0.47
# 87               1.00              1.00       0.00      0.50
# 88               0.00              0.00       0.00      0.00
# 89               1.00              0.78       0.00      0.67
# 90               1.00              0.80       0.00      0.45
# 91               0.89              0.73       0.20      0.69
# 92               0.89              0.72       0.06      0.40
# 93               0.94              0.80       0.04      0.45
# 94               0.89              0.75       0.08      0.47
# 95               0.90              0.73       0.08      0.50
# 96               1.00              1.00       0.00      0.25
# 97               0.91              0.73       0.07      0.50
# 98               0.92              0.79       0.09      0.57
# 99               0.93              0.78       0.09      0.59
# 100              0.93              0.76       0.10      0.61
# 101              1.00              0.33       0.00      0.60
# 102              0.90              0.74       0.06      0.40
# 103              0.93              0.89       0.06      0.45
# 104              0.90              0.78       0.08      0.46
# 105              0.89              0.76       0.09      0.49
# 106              0.83              1.00       0.17      0.45
# 107              0.96              0.82       0.03      0.45
# 108              1.00              1.00       0.00      0.50
# 109              0.93              0.83       0.09      0.57
# 110              0.98              0.83       0.08      0.82
# 111              0.91              0.73       0.07      0.51
# 112              0.92              0.74       0.08      0.54
# 113              0.91              0.73       0.10      0.58
# 114              0.90              0.74       0.09      0.52
# 115              0.88              0.58       0.06      0.40
# 116              0.93              0.72       0.08      0.60
# 117              0.93              0.75       0.10      0.65
# 118              0.94              0.74       0.10      0.67
# 119              0.92              0.73       0.10      0.61
# 120              0.96              0.70       0.06      0.66
# 121              0.91              0.75       0.08      0.51
# 122              0.91              0.77       0.09      0.53
# 123              0.91              0.75       0.10      0.55
# 124              0.88              0.77       0.10      0.49
# 125              0.92              0.79       0.06      0.46
# 126              0.93              0.81       0.02      0.22
# 127              1.00              0.70       0.00      0.77
# 128              0.91              0.77       0.04      0.31
# 129              0.90              0.69       0.07      0.49
# All requested tables have been displayed.
